# %%
import pandas as pd

# %%
pd.read_csv('houses_and_apartments_for_rent.csv').head()
# Out:
#                                                title  rent_per_period  \
# 0               2bdrm Apartment in Kilimani for Rent            55000
# 1                       Bedsitors To Let In Kilimani            18000
# 2                1bdrm Apartment in Jamhuri for Rent            25000
# 3  Executive One Bedroom Fully Furnished in Kilim...           100000
# 4               1bdrm Apartment in Kilimani for rent            25000
#
#   rent_period                   region  property_size_sqm  bedrooms  \
# 0   per month        Nairobi, Kilimani             1234.0       2.0
# 1         NaN        Nairobi, Kilimani             1234.0       1.0
# 2   per month  Jamhuri, Jamhuri Estate             1234.0       1.0
# 3   per month        Nairobi, Kilimani             1234.0       1.0
# 4   per month        Nairobi, Kilimani             1234.0       1.0
#
#    bathrooms   furnishing listing_by  user_id  ...  status  \
# 0        1.0  Unfurnished        NaN  2385290  ...  active
# ...
